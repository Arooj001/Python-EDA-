# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:/Users/user/Downloads/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.columns.str.strip()
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
s = pd.Series(['1. Bat. ', '2. Dog\\n', '3. Animal?\\', np.nan ])
s
# Out:
# 0       1. Bat.
# 1       2. Dog\n
# 2    3. Animal?\
# 3            NaN
# dtype: object

# %%
s.str.strip('123!? \\n.')
# Out:
# 0       Bat
# 1       Dog
# 2    Animal
# 3       NaN
# dtype: object

# %%
s.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include=['object'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.describe(include=['bool','object'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.head(11)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.tail(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = df.sort_values(['DistanceFromHome'], ascending=0)
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 352    48        No      Travel_Rarely        530                   Sales
# 875    44        No      Travel_Rarely        200  Research & Development
# 792    33       Yes  Travel_Frequently        827  Research & Development
# 1434   52        No         Non-Travel        585                   Sales
# 1109   30        No      Travel_Rarely       1288                   Sales
# ...   ...       ...                ...        ...                     ...
# 1121   36        No      Travel_Rarely        884                   Sales
# 1117   34        No      Travel_Rarely       1351  Research & Development
# 414    24       Yes      Travel_Rarely       1448                   Sales
# 1113   32        No         Non-Travel       1200  Research & Development
# 0      41       Yes      Travel_Rarely       1102                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df1 = df.sort_values(['DistanceFromHome'])
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1121   36        No      Travel_Rarely        884                   Sales
# 414    24       Yes      Travel_Rarely       1448                   Sales
# 1135   46        No      Travel_Rarely        563                   Sales
# 400    39        No  Travel_Frequently       1218  Research & Development
# ...   ...       ...                ...        ...                     ...
# 875    44        No      Travel_Rarely        200  Research & Development
# 979    34        No      Travel_Rarely        285  Research & Development
# 604    42        No      Travel_Rarely        933  Research & Development
# 425    50        No      Travel_Rarely       1099  Research & Development
# 259    31       Yes  Travel_Frequently        307  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df1 = df.sort_values(['DailyRate'])
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 649    53        No      Travel_Rarely        102  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 1110   35       Yes      Travel_Rarely        104  Research & Development
# 1437   39        No         Non-Travel        105  Research & Development
# 310    31        No      Travel_Rarely        106         Human Resources
# ...   ...       ...                ...        ...                     ...
# 1202   38        No      Travel_Rarely       1495  Research & Development
# 155    29        No         Non-Travel       1496  Research & Development
# 1056   28       Yes  Travel_Frequently       1496                   Sales
# 986    39        No      Travel_Rarely       1498                   Sales
# 427    60        No  Travel_Frequently       1499                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df1 = df.sort_values(['DailyRate'], ascending=False)
df1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 427    60        No  Travel_Frequently       1499                   Sales
# 986    39        No      Travel_Rarely       1498                   Sales
# 155    29        No         Non-Travel       1496  Research & Development
# 1056   28       Yes  Travel_Frequently       1496                   Sales
# 1202   38        No      Travel_Rarely       1495  Research & Development
# ...   ...       ...                ...        ...                     ...
# 310    31        No      Travel_Rarely        106         Human Resources
# 1437   39        No         Non-Travel        105  Research & Development
# 1110   35       Yes      Travel_Rarely        104  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 649    53        No      Travel_Rarely        102  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df1 = df.sort_values(['DailyRate'])
df1.head(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 649    53        No      Travel_Rarely        102  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 1110   35       Yes      Travel_Rarely        104  Research & Development
# 1437   39        No         Non-Travel        105  Research & Development
# 310    31        No      Travel_Rarely        106         Human Resources
# 884    40        No      Travel_Rarely        107                   Sales
# 732    30       Yes  Travel_Frequently        109  Research & Development
# 862    44        No         Non-Travel        111  Research & Development
# 82     55        No      Travel_Rarely        111                   Sales
# 173    30        No         Non-Travel        111  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 649                 23          4     Life Sciences              1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df_obj = df.select_dtypes(['object'])
df_obj
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
df_int = df.select_dtypes(['int'])
df_int
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
df['DailyRate'].nunique()
# Out:
# 886

# %%
df['Education'].nunique()
# Out:
# 5

# %%
df['EmployeeNumber'].nunique()
# Out:
# 1470

# %%
df['HourlyRate'].unique()
# Out:
# array([ 94,  61,  92,  56,  40,  79,  81,  67,  44,  84,  49,  31,  93,
#         50,  51,  80,  96,  78,  45,  82,  53,  83,  58,  72,  48,  42,
#         41,  86,  97,  75,  33,  37,  73,  98,  36,  47,  71,  30,  43,
#         99,  59,  95,  57,  76,  87,  66,  55,  32,  52,  70,  62,  64,
#         63,  60, 100,  46,  39,  77,  35,  91,  54,  34,  90,  65,  88,
#         85,  89,  68,  69,  74,  38], dtype=int64)

# %%
df['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
for column in df:
print("Column", " ",column," uniquevalue are :" , df[column].nunique())
print(df[column].unique())
print("--------------------------")
# Out:
#   Cell In[79], line 2
#     print("Column", " ",column," uniquevalue are :" , df[column].nunique())
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
for column in df:
    print("Column", " ",column," uniquevalue are :" , df[column].nunique())
    print(df[column].unique())
    print("--------------------------")
# Out:
# Column   Age  uniquevalue are : 43
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# --------------------------
# Column   Attrition  uniquevalue are : 2
# ['Yes' 'No']
# --------------------------
# Column   BusinessTravel  uniquevalue are : 3
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# --------------------------
# Column   DailyRate  uniquevalue are : 886
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
df['DailyRate'].value_counts()
# Out:
# DailyRate
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: count, Length: 886, dtype: int64

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
df['WorkLifeBalance'].value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
df['PercentSalaryHike'].value_counts()
# Out:
# PercentSalaryHike
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
df['Attrition'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1470, dtype: bool

# %%
df['Attrition'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
for column in df:
    print("Column name:",column, " missingvalues: ", df[column].isnull().sum())
    print("----------------------------------")
# Out:
# Column name: Age  missingvalues:  0
# ----------------------------------
# Column name: Attrition  missingvalues:  0
# ----------------------------------
# Column name: BusinessTravel  missingvalues:  0
# ----------------------------------
# Column name: DailyRate  missingvalues:  0
# ----------------------------------
# Column name: Department  missingvalues:  0
# ----------------------------------
# Column name: DistanceFromHome  missingvalues:  0
# ----------------------------------
# Column name: Education  missingvalues:  0
# ----------------------------------
# Column name: EducationField  missingvalues:  0
# ----------------------------------
# Column name: EmployeeCount  missingvalues:  0
# ----------------------------------
# Column name: EmployeeNumber  missingvalues:  0
# ----------------------------------
# Column name: EnvironmentSatisfaction  missingvalues:  0
# ----------------------------------
# Column name: Gender  missingvalues:  0
# ...

# %%
for column in df:
    print("Column", " ",column," uniquevalue are :" , df[column].nunique())
    print(df[column].value_counts())
    print("--------------------------")
# Out:
# Column   Age  uniquevalue are : 43
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
# --------------------------
# Column   Attrition  uniquevalue are : 2
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# --------------------------
# Column   BusinessTravel  uniquevalue are : 3
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# --------------------------
# Column   DailyRate  uniquevalue are : 886
# DailyRate
# 691     6
# 408     5
# ...

# %%
def data(data):
    print("-------------column--------------")
    print(data.columns)
    print("-------------info--------------")
    print(data.info())
    print("-------------shape--------------")
    print(data.shape)
    print("-------------duplicate--------------")
    print(data.duplicated())
    print("-------------column types--------------")
    print(data.dtypes)
    print("-------------missing values sum--------------")
    print(data.isnull().sum())
    print("------------------end---------------")

# %%
data(df)
# Out:
# -------------column--------------
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
# -------------info--------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ...

# %%
df[df['Attrition']=='Yes']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.groupby(['WorkLifeBalance']).mean(numeric_only=True)
# Out:
#                        Age   DailyRate  DistanceFromHome  Education  \
# WorkLifeBalance
# 1                37.287500  812.100000          9.425000   2.975000
# 2                37.188953  827.459302          9.325581   2.857558
# 3                36.849944  798.409854          9.277716   2.927212
# 4                36.568627  765.098039          8.274510   2.921569
#
#                  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# WorkLifeBalance
# 1                          1.0     1014.237500                 2.650000
# 2                          1.0     1026.511628                 2.671512
# 3                          1.0     1019.240761                 2.744681
# 4                          1.0     1059.549020                 2.738562
#
#                  HourlyRate  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                                        ...
# 1                 63.800000        2.737500  1.875000  ...           3.175000
# ...

# %%
df.groupby(['DailyRate']).mean(numeric_only=True)
# Out:
#                  Age  DistanceFromHome  Education  EmployeeCount  \
# DailyRate
# 102        53.000000         23.000000        4.0            1.0
# 103        28.000000         24.000000        3.0            1.0
# 104        35.000000          2.000000        3.0            1.0
# 105        39.000000          9.000000        3.0            1.0
# 106        31.000000          2.000000        3.0            1.0
# ...              ...               ...        ...            ...
# 1492       40.000000         20.000000        4.0            1.0
# 1495       41.666667          6.333333        3.0            1.0
# 1496       28.500000          1.000000        2.0            1.0
# 1498       39.000000         21.000000        4.0            1.0
# 1499       60.000000         28.000000        3.0            1.0
#
#            EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# DailyRate
# 102            901.000000                 4.000000   72.000000
# ...

# %%
df.groupby(['EmployeeCount']).mean(numeric_only=True)
# Out:
#                     Age   DailyRate  DistanceFromHome  Education  \
# EmployeeCount
# 1              36.92381  802.485714          9.192517   2.912925
#
#                EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# EmployeeCount
# 1                 1024.865306                 2.721769   65.891156
#
#                JobInvolvement  JobLevel  JobSatisfaction  ...  \
# EmployeeCount                                             ...
# 1                    2.729932  2.063946         2.728571  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeCount
# 1                              2.712245           80.0          0.793878
#
#                TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeCount
# 1                      11.279592                2.79932         2.761224
#
#                YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeCount
# ...

# %%
df.groupby(['WorkLifeBalance']).median(numeric_only=True)
# Out:
#                   Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# WorkLifeBalance
# 1                35.5      762.0               7.0        3.0            1.0
# 2                35.5      824.0               7.0        3.0            1.0
# 3                36.0      805.0               7.0        3.0            1.0
# 4                35.0      703.0               5.0        3.0            1.0
#
#                  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# WorkLifeBalance
# 1                         990.0                      3.0        61.5
# 2                        1045.5                      3.0        67.0
# 3                        1009.0                      3.0        66.0
# 4                        1106.0                      3.0        64.0
#
#                  JobInvolvement  JobLevel  ...  PerformanceRating  \
# WorkLifeBalance                            ...
# 1                           3.0       2.0  ...                3.0
# ...

# %%
df.groupby(['DailyRate']).median(numeric_only=True)
# Out:
#             Age  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# DailyRate
# 102        53.0              23.0        4.0            1.0           901.0
# 103        28.0              24.0        3.0            1.0            19.0
# 104        35.0               2.0        3.0            1.0          1569.0
# 105        39.0               9.0        3.0            1.0          2022.0
# 106        31.0               2.0        3.0            1.0           424.0
# ...         ...               ...        ...            ...             ...
# 1492       40.0              20.0        4.0            1.0          1092.0
# 1495       38.0               5.0        3.0            1.0          1473.0
# 1496       28.5               1.0        2.0            1.0           847.0
# 1498       39.0              21.0        4.0            1.0          1390.0
# 1499       60.0              28.0        3.0            1.0           573.0
#
# ...

# %%
df.groupby(['EmployeeCount']).mean(numeric_only=True)
# Out:
#                     Age   DailyRate  DistanceFromHome  Education  \
# EmployeeCount
# 1              36.92381  802.485714          9.192517   2.912925
#
#                EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# EmployeeCount
# 1                 1024.865306                 2.721769   65.891156
#
#                JobInvolvement  JobLevel  JobSatisfaction  ...  \
# EmployeeCount                                             ...
# 1                    2.729932  2.063946         2.728571  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeCount
# 1                              2.712245           80.0          0.793878
#
#                TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeCount
# 1                      11.279592                2.79932         2.761224
#
#                YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeCount
# ...

# %%
df.groupby(['WorkLifeBalance'])['HourlyRate'].mean()
# Out:
# WorkLifeBalance
# 1    63.800000
# 2    66.502907
# 3    66.090705
# 4    64.444444
# Name: HourlyRate, dtype: float64

# %%
df.groupby(['BusinessTravel'])['HourlyRate'].mean()
# Out:
# BusinessTravel
# Non-Travel           64.866667
# Travel_Frequently    65.097473
# Travel_Rarely        66.249281
# Name: HourlyRate, dtype: float64

# %%
df.groupby(['WorkLifeBalance'])[['HourlyRate', 'EmployeeNumber']].mean()
# Out:
#                  HourlyRate  EmployeeNumber
# WorkLifeBalance
# 1                 63.800000     1014.237500
# 2                 66.502907     1026.511628
# 3                 66.090705     1019.240761
# 4                 64.444444     1059.549020

# %%
df.groupby(['Age'])[['StandardHours', 'DailyRate']].mean()
# Out:
#      StandardHours   DailyRate
# Age
# 18            80.0  747.625000
# 19            80.0  548.444444
# 20            80.0  819.454545
# 21            80.0  762.846154
# 22            80.0  806.937500
# 23            80.0  707.928571
# 24            80.0  863.115385
# 25            80.0  768.076923
# 26            80.0  844.769231
# 27            80.0  907.333333
# 28            80.0  927.500000
# 29            80.0  779.308824
# 30            80.0  791.266667
# 31            80.0  725.173913
# 32            80.0  766.262295
# 33            80.0  739.672414
# 34            80.0  788.285714
# 35            80.0  825.320513
# 36            80.0  819.130435
# 37            80.0  827.720000
# 38            80.0  776.155172
# 39            80.0  774.642857
# 40            80.0  841.719298
# 41            80.0  721.525000
# 42            80.0  713.391304
# 43            80.0  818.250000
# 44            80.0  856.848485
# 45            80.0  844.975610
# 46            80.0  802.242424
# ...

# %%
df.groupby(['DistanceFromHome'])[['Education', 'TotalWorkingYears']].mean()
# Out:
#                   Education  TotalWorkingYears
# DistanceFromHome
# 1                  2.980769          11.283654
# 2                  2.829384          12.355450
# 3                  2.773810          11.023810
# 4                  2.703125          11.359375
# 5                  2.953846          10.184615
# 6                  2.898305          11.949153
# 7                  2.952381          12.690476
# 8                  2.850000          11.025000
# 9                  2.988235           9.611765
# 10                 3.058140           9.918605
# 11                 2.931034           9.965517
# 12                 3.100000          10.700000
# 13                 3.000000           9.526316
# 14                 2.857143          12.904762
# 15                 2.653846          10.769231
# 16                 3.062500           9.781250
# 17                 2.900000           9.350000
# 18                 3.153846          12.000000
# 19                 2.772727           8.681818
# ...

# %%
df['JobRole'].nunique()
# Out:
# 9

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df['HourlyRate'].nunique()
# Out:
# 71

# %%
df['DistanceFromHome'].nunique()
# Out:
# 29

# %%
df['DistanceFromHome'].unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13], dtype=int64)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.groupby(['JobRole'])['Age'].std()
# Out:
# JobRole
# Healthcare Representative    8.200483
# Human Resources              7.937254
# Laboratory Technician        8.419382
# Manager                      6.941305
# Manufacturing Director       8.622584
# Research Director            7.923687
# Research Scientist           8.592472
# Sales Executive              8.092546
# Sales Representative         8.513373
# Name: Age, dtype: float64

# %%
df.groupby(['JobRole']).agg({'Age':[np.mean,np.std], 'HourlyRate':[np.mean,'count'],'Education':'nunique'})
# Out:
#                                  Age           HourlyRate       Education
#                                 mean       std       mean count   nunique
# JobRole
# Healthcare Representative  39.809160  8.200483  66.839695   131         5
# Human Resources            35.500000  7.937254  64.173077    52         5
# Laboratory Technician      34.096525  8.419382  66.683398   259         5
# Manager                    46.764706  6.941305  66.833333   102         5
# Manufacturing Director     38.296552  8.622584  65.006897   145         5
# Research Director          44.000000  7.923687  63.762500    80         5
# Research Scientist         34.236301  8.592472  66.708904   292         5
# Sales Executive            36.889571  8.092546  65.438650   326         5
# Sales Representative       30.361446  8.513373  64.337349    83         4

# %%
df.groupby(['JobRole']).agg({'Age':[np.mean,np.std], 'HourlyRate':[np.mean,'count'],'Education':'unique'})
# Out:
#                                  Age           HourlyRate        \
#                                 mean       std       mean count
# JobRole
# Healthcare Representative  39.809160  8.200483  66.839695   131
# Human Resources            35.500000  7.937254  64.173077    52
# Laboratory Technician      34.096525  8.419382  66.683398   259
# Manager                    46.764706  6.941305  66.833333   102
# Manufacturing Director     38.296552  8.622584  65.006897   145
# Research Director          44.000000  7.923687  63.762500    80
# Research Scientist         34.236301  8.592472  66.708904   292
# Sales Executive            36.889571  8.092546  65.438650   326
# Sales Representative       30.361446  8.513373  64.337349    83
#
#                                  Education
#                                     unique
# JobRole
# Healthcare Representative  [3, 4, 2, 1, 5]
# Human Resources            [2, 4, 1, 3, 5]
# Laboratory Technician      [2, 1, 3, 4, 5]
# ...

# %%
df[df['Attrition']=='Yes']
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df[df['DistanceFromHome']==24]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 7      30        No      Travel_Rarely       1358  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 163    57        No      Travel_Rarely        334  Research & Development
# 243    40        No      Travel_Rarely       1300  Research & Development
# 286    44       Yes  Travel_Frequently        920  Research & Development
# 305    36        No         Non-Travel       1105  Research & Development
# 451    42        No      Travel_Rarely        319  Research & Development
# 463    26       Yes      Travel_Rarely        471  Research & Development
# 470    24        No  Travel_Frequently        535                   Sales
# 543    44        No         Non-Travel        381  Research & Development
# 558    32        No  Travel_Frequently        430  Research & Development
# 706    40       Yes         Non-Travel       1479                   Sales
# ...

# %%
df.loc[(df['Department'] == 'Research & Development') & (df.Education == 2)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# 13     34        No      Travel_Rarely       1346  Research & Development
# 16     32        No      Travel_Rarely        334  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1425   33        No      Travel_Rarely        501  Research & Development
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df['Department'] == 'Research & Development') & ~(df.Education == 2)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1463   31        No         Non-Travel        325  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[df.EducationField.isin(['Medical','Life Sciences'])]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[df.EducationField.isin(['Other'])]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 2      37       Yes  Travel_Rarely       1373  Research & Development
# 20     24        No     Non-Travel        673  Research & Development
# 25     53        No  Travel_Rarely       1282  Research & Development
# 31     44        No  Travel_Rarely       1459  Research & Development
# 40     35        No  Travel_Rarely        464  Research & Development
# ...   ...       ...            ...        ...                     ...
# 1408   23        No  Travel_Rarely        571  Research & Development
# 1413   25        No  Travel_Rarely        977  Research & Development
# 1433   25        No  Travel_Rarely       1382                   Sales
# 1459   29        No  Travel_Rarely       1378  Research & Development
# 1464   26        No  Travel_Rarely       1167                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df['EducationField'] == 'Life Sciences') | (df['EducationField'] =='Medical')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.loc[(df['Department'] == 'Research & Development') & (df.Education == 2) | (df['Department'] == 'Sale')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# 13     34        No      Travel_Rarely       1346  Research & Development
# 16     32        No      Travel_Rarely        334  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1425   33        No      Travel_Rarely        501  Research & Development
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1459   29        No      Travel_Rarely       1378  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df["current status"] = 'employed'
df['current status']
# Out:
# 0       employed
# 1       employed
# 2       employed
# 3       employed
# 4       employed
#           ...
# 1465    employed
# 1466    employed
# 1467    employed
# 1468    employed
# 1469    employed
# Name: current status, Length: 1470, dtype: object

# %%
df["random"] = 10
df['random']
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 1465    10
# 1466    10
# 1467    10
# 1468    10
# 1469    10
# Name: random, Length: 1470, dtype: int64

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102       Sale
# 1      49        No  Travel_Frequently        279       Sale
# 2      37       Yes      Travel_Rarely       1373       Sale
# 3      33        No  Travel_Frequently       1392       Sale
# 4      27        No      Travel_Rarely        591       Sale
# ...   ...       ...                ...        ...        ...
# 1465   36        No  Travel_Frequently        884       Sale
# 1466   39        No      Travel_Rarely        613       Sale
# 1467   27        No      Travel_Rarely        155       Sale
# 1468   49        No  Travel_Frequently       1023       Sale
# 1469   34        No      Travel_Rarely        628       Sale
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...
